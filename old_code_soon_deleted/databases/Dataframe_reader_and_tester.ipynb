# %%
import pandas as pd

# %%
df_part1 = pd.read_csv("project/data/processed_data_part1.csv")
print(df_part1.shape[0])
df_part1.head()
# Out:
# 29425
#        PMID                                              Title  \
# 0  24645995  α-1 antitrypsin and chronic fatigue syndrome: ...
# 1  24565439          A data-driven acute inflammation therapy.
# 2  24505723  Voxelwise spectral diffusional connectivity an...
# 3  24472488  Systems integrity in health and aging - an ani...
# 4  24460364  Multi-agent systems: effective approach for ca...
#
#                                             Abstract  \
# 0  SUMMARY Several lines of evidence support the ...
# 1  Acute inflammation is a severe medical conditi...
# 2  Human brain connectivity can be studied using ...
# 3  Human lifespan is positively correlated with c...
# 4  Physicians in order to study the causes of can...
#
#                                              Authors Publication Date  \
# 0     Jose Alegre Sandra Camprubi Ana GarciaQuintana         2013-Mar
# 1  Vladan Radosavljevic Kosta Ristovski Zoran Obr...             2013
# 2  Junning Li Yan Jin Yonggang Shi Ivo D Dinov Da...             2013
# 3                      Marije Oostindjer Gro V Amdam      2013-Jan-07
# 4    Niloofar Mohammadzadeh Reza Safdari Azin Rahimi             2013
#
#                              DOI
# 0              10.2217/pmt.12.84
# 1      10.1186/1755-8794-6-S3-S7
# 2   10.1007/978-3-642-40811-3_82
# 3          10.1186/2046-2395-2-2
# 4  10.7314/apjcp.2013.14.12.7757

# %%
df_part2 = pd.read_csv("project/data/processed_data_part2.csv")
print(df_part2.shape[0])
df_part2.head()
# Out:
# 29425
#        PMID                                              Title  \
# 0  34939142  [Use of medical archives for research and pati...
# 1  34937811  Impact of salt intake on urinary albumin excre...
# 2  34937459  Application and prospect of artificial intelli...
# 3  34936982  Reducing Cybersickness in 360-Degree Virtual R...
# 4  34936469  Toward an Optimized Staging System for Pancrea...
#
#                                             Abstract  \
# 0  In recent years technology in healthcare has e...
# 1  Diabetic kidney disease is an important and co...
# 2  With the progress of science and technology ar...
# 3  Despite the technological advancements in Virt...
# 4  The American Joint Committee on Cancer AJCC ei...
#
#                                              Authors Publication Date  \
# 0                                   M Peredin S Baur         2022-Feb
# 1  Yuka Kotake Shigehiro Karashima Masaki Kawakam...      2022-May-30
# 2  Huangming Zhuang Anyu Bao Yulin Tan Hanyu Wang...         2022-Jan
# 3  Iqra Arshad Paulo De Mello Martin Ender Jason ...      2021-Dec-16
# 4  Dimitris Bertsimas Georgios Antonios Margonis ...         2021-Dec
#
#                              DOI
# 0     10.1007/s00120-021-01742-y
# 1      10.1507/endocrj.EJ21-0447
# 2  10.1080/17474124.2022.2020646
# 3      10.1163/22134808-bja10066
# 4           10.1200/CCI.21.00001

# %%
df_part1[999:1000]
# Out:
#          PMID                                              Title  \
# 999  24195205  [Clinical research on children mental retardat...
#
#                                               Abstract  \
# 999  To observe the impacts of acupuncture on intel...
#
#                                                Authors Publication Date  \
# 999  JinBai Huang HuiFang Cao Jiao Hu LongHao Liu Z...         2013-Aug
#
#          DOI
# 999  Unknown
